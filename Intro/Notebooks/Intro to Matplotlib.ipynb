# %% [markdown]
# ___
# # Matplotlib Overview Lecture

# %% [markdown]
# Official Matplotlib documentation: http://matplotlib.org/
#
# ## Installation
#
# ```pip3 install matplotlib```

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You'll also need to use this line to see plots in the notebook (works only in jupyter notebook):

# %%
# %matplotlib inline

# %% [markdown]
# ### Example

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ## Basic Matplotlib Commands
#
# We can create a very simple line plot using the following ( I encourage you to pause and use Shift+Tab along the way to check out the document strings for the functions we are using).

# %%
plt.plot(x, y, 'r') # 'r' stands for red
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Title Here')
plt.show()

# %% [markdown]
# ## Creating Multiple Plots on Same Canvas

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
plt.subplot(2,2,1)
plt.plot(x, y, 'r--')
plt.subplot(2,2,2)
plt.plot(y, x, 'g*-');
plt.subplot(2,2,3)
plt.plot(x, y, 'b--')
plt.subplot(2,2,4)
plt.plot(y, x, 'y*-');

# %% [markdown]
# ## Object Oriented Method

# %% [markdown]
# We create figure objects and then just call methods or attributes off of that object.
# To begin we create a figure instance. Then we can add axes to that figure:

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Plot on that set of axes
plt.plot(x, y, 'b')
plt.xlabel('Set X Label') # Notice the use of set_ to begin methods
plt.ylabel('Set y Label')
plt.title('Set Title')
# Out:
# Text(0.5,1,'Set Title')

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0.7, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes
axes3 = fig.add_axes([0.0, 0.0, 0.4, 0.4]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

axes3.plot(x**3, x, 'g')
axes3.set_xlabel('X_label_axes2')
axes3.set_ylabel('Y_label_axes2')
axes3.set_title('Axes 3 Title');

# %% [markdown]
# ## subplots()

# %%
fig, axes = plt.subplots()

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
# Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
fig, axes = plt.subplots(nrows=3, ncols=4)
fig.tight_layout()

# %%
# Axes is an array of axes to plot on
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba6526d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba5be5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba5e3c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba595358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba53ea20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba56f0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba518748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba4bedd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba472470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba499b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba44a1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f10ba3f2860>]],
#       dtype=object)

# %% [markdown]
# A common issue with matplolib is overlapping subplots or figures. We can use **fig.tight_layout()** or **plt.tight_layout()** method, which automatically adjusts the positions of the axes on the figure canvas so that there is no overlapping content:

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)


axes[0].plot(x, y, 'r')
axes[1].plot(x, y, 'g')
axes[0].set_title('First Plot')
axes[1].set_title('Second Plot')

plt.tight_layout()

# %% [markdown]
# ### Figure size

# %%
fig = plt.figure(figsize=(28,4)) #,2
ax=fig.add_axes([0,0,0.2,0.2])
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(30,14)) #,2
ax=fig.add_axes([0,0,0.2,0.2])
ax.plot(x,y)

# %% [markdown]
# The same arguments can also be passed to layout managers, such as the `subplots` function:

# %%
fig, axes = plt.subplots(nrows=2 ,ncols=1, figsize=(15,5))

axes[0].plot(x, y, 'r')
axes[1].plot(y, x, 'b')
plt.tight_layout()

# %% [markdown]
# ## Saving figures

# %%
fig.savefig("filename.png")

# %% [markdown]
# Here we can also optionally specify the DPI (dots per inch) and choose between different output formats:

# %%
fig.savefig("filename1.jpg", dpi=200)

# %% [markdown]
# ____
# ## Legends, labels and titles

# %% [markdown]
# **Figure titles**
#
# A title can be added to each axis instance in a figure.

# %%
ax.set_title("title");

# %% [markdown]
# **Axis labels**

# %%
ax.set_xlabel("x")
ax.set_ylabel("y");

# %% [markdown]
# ### Legends

# %% [markdown]
# You can use the **label="label text"** keyword argument when plots or other objects are added to the figure, and then using the **legend** method without arguments to add the legend to the figure:

# %%
fig = plt.figure(figsize=(8,5))

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend(loc=(0.7,0.2))  #

# %% [markdown]
# Avoid legend overlapping

# %%
ax.legend(loc=1) # upper right corner
ax.legend(loc=2) # upper left corner
ax.legend(loc=3) # lower left corner
ax.legend(loc=4) # lower right corner


ax.legend(loc=0) # let matplotlib decide the optimal location
fig

# %% [markdown]
# ## Setting colors, linewidths, linetypes

# %%
# MATLAB style line color and style 
fig, ax = plt.subplots()
ax.plot(x, x**2, 'bv-') # blue line with dots
ax.plot(x, x**3, 'g--') # green dashed line

# %% [markdown]
# ### Colors with the color= parameter

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color="blue", alpha=0.1) # half-transparant
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")        # RGB hex code

# %% [markdown]
# ### Line and marker styles

# %% [markdown]
# To change the line width, we can use the `linewidth` or `lw` keyword argument. The line style can be selected using the `linestyle` or `ls` keyword arguments:

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# ### Control over axis appearance

# %% [markdown]
# In this section we will look at controlling axis sizing properties in a matplotlib figure.

# %% [markdown]
# ## Plot range

# %% [markdown]
# We can configure the ranges of the axes using the `set_ylim` and `set_xlim` methods in the axis object, or `axis('tight')` for automatically getting "tightly fitted" axes ranges:

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %% [markdown]
# # Special Plot Types

# %%
plt.scatter(x,y)

# %%
x = np.random.rand(1,50)
y = np.random.rand(1,50)
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000), 100)

# %%
plt.hist(data,bins=50)
plt.show()

# %%
plt.hist(data,bins=20)
plt.show()

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=False);

# %% [markdown]
# ## Further reading

# %% [markdown]
# * http://www.matplotlib.org - The project web page for matplotlib.
# * https://github.com/matplotlib/matplotlib - The source code for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.
